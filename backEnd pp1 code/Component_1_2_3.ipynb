# %%
# import libraries

import pandas as pd
import numpy as np
import string
import re
from textblob import TextBlob
import googletrans
from googletrans import Translator
from googletrans import LANGUAGES
translator = Translator()

# %% [markdown]
# ### Component-01

# %%
# import dataset

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
xl_data = pd.read_excel(r'C:\Users\Sajee\Desktop\Research-2023 group\backEnd\MasterMovie-comment - 1.xlsx')
xl_data
# Out:
#                                     Original_Comments
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1                    I am Vijay fan since i was kid….
# 2                           மிக மிக அருமையான ட்ரைலர்.
# 3                     Vijay Sethupati is far better!!
# 4                                         நேரம் வீண்🤛
# 5                                    വിജയ് ♥️♥️♥️♥️♥️
# 6                            நெருப்பு!!!🔥 வேற லெவல் 😎
# 7               will it be available in Hindi dubbed?
# 8                 বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9                                      மிக மிக அருமை!
# 10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11            Nalla thiraipadam pola....nalla irukum.
# 12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14  Super trailer!!!!super action, super V.i and V...
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...

# %%
# data cleaning - Remove punctuation marks

punctuation = '''!()@#&:;🤜🤛🎂😎💚...❤/%?\{}$,-😂🙏*👇🔥😢👹💘😊👍👎👊😣🤕😈😄☠😭1234567890😀💗🥰😍💯🤩♥️🤘👈✌️🙂💪✊🏿😘🥳🤟😫😊💖️🌹👌🥳🤗🤮🤢🎬🥳🤯😇🤣🏽😃💥🤔'''
def remove_punct(cmt):
    cmt_nonpunct = "".join([ char for char in cmt if char not in punctuation])  #--- for char in cmt: ----
                                                                                #---   if( char not in punctuation ): ----                               
    return cmt_nonpunct

xl_data['Cleaned_Comments'] = xl_data['Original_Comments'].apply(lambda x: remove_punct(x))
xl_data
# Out:
#                                     Original_Comments  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1                    I am Vijay fan since i was kid….
# 2                           மிக மிக அருமையான ட்ரைலர்.
# 3                     Vijay Sethupati is far better!!
# 4                                         நேரம் வீண்🤛
# 5                                    വിജയ് ♥️♥️♥️♥️♥️
# 6                            நெருப்பு!!!🔥 வேற லெவல் 😎
# 7               will it be available in Hindi dubbed?
# 8                 বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9                                      மிக மிக அருமை!
# 10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11            Nalla thiraipadam pola....nalla irukum.
# 12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14  Super trailer!!!!super action, super V.i and V...
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...
#
#                                      Cleaned_Comments
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1                     I am Vijay fan since i was kid…
# 2                            மிக மிக அருமையான ட்ரைலர்
# 3                       Vijay Sethupati is far better
# 4                                          நேரம் வீண்
# 5                                              വിജയ്
# 6                                 நெருப்பு வேற லெவல்
# 7                will it be available in Hindi dubbed
# 8                   বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই
# 9                                       மிக மிக அருமை
# 10                                        තලපති විජේ
# 11                 Nalla thiraipadam polanalla irukum
# 12       ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ
# 13                     Anirudh  best music director
# 14   Super trailersuper action super Vi and VS acting
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...

# %%
#Language detection & translate to common-language(english)

translated_words = []
src_language = []
dest_language = []

for element in xl_data['Cleaned_Comments']:
    translated_words.append(translator.translate(element).text)
    src_language.append(LANGUAGES[ translator.translate(element).src] )
    dest_language.append(LANGUAGES[ translator.translate(element).dest] )
    
# print(translated_words)
# print(src_language)
# print(dest_language)
    
xl_data['Source_Language'] = src_language
xl_data['destination_Language'] = dest_language
xl_data['English_Comments'] = translated_words

xl_data
# Out:
#                                     Original_Comments  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1                    I am Vijay fan since i was kid….
# 2                           மிக மிக அருமையான ட்ரைலர்.
# 3                     Vijay Sethupati is far better!!
# 4                                         நேரம் வீண்🤛
# 5                                    വിജയ് ♥️♥️♥️♥️♥️
# 6                            நெருப்பு!!!🔥 வேற லெவல் 😎
# 7               will it be available in Hindi dubbed?
# 8                 বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9                                      மிக மிக அருமை!
# 10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11            Nalla thiraipadam pola....nalla irukum.
# 12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14  Super trailer!!!!super action, super V.i and V...
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...
#
#                                      Cleaned_Comments Source_Language  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...           tamil
# 1                     I am Vijay fan since i was kid…         english
# 2                            மிக மிக அருமையான ட்ரைலர்           tamil
# 3                       Vijay Sethupati is far better         english
# 4                                          நேரம் வீண்           tamil
# 5                                              വിജയ്        malayalam
# 6                                 நெருப்பு வேற லெவல்            tamil
# 7                will it be available in Hindi dubbed         english
# 8                   বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই         bengali
# 9                                       மிக மிக அருமை           tamil
# 10                                        තලපති විජේ          sinhala
# 11                 Nalla thiraipadam polanalla irukum           tamil
# 12       ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ          sinhala
# 13                     Anirudh  best music director           english
# 14   Super trailersuper action super Vi and VS acting         english
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...           tamil
#
#    destination_Language                                   English_Comments
# 0               english  It seems that the storyline of the film is better
# 1               english                    I am Vijay fan since i was kid…
# 2               english                          The most precious trailer
# 3               english                     Vijay Sethupathi is far better
# 4               english                                      Waste of time
# 5               english                                              Vijay
# 6               english                          Fire is a different level
# 7               english               will it be available in Hindi dubbed
# 8               english                 Want to see Bangladeshi Vijay fans
# 9               english                                             Decent
# 10              english                                    Boilapity Vijay
# 11              english                          Good movie is not Polonna
# 12              english                 The Lankawa set a lichoe for a gum
# 13              english                       Anirudh  best music director
# 14              english   Super trailersuper action super Vi and VS acting
# 15              english  An actor responsible for a community has inspi...

# %%
# Tokenization

def tokenize(cmt):
    tokens = re.split('\W+', cmt)
    return tokens

xl_data['tokens'] = xl_data['English_Comments'].apply(lambda x: tokenize(x))
xl_data
# Out:
#                                     Original_Comments  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1                    I am Vijay fan since i was kid….
# 2                           மிக மிக அருமையான ட்ரைலர்.
# 3                     Vijay Sethupati is far better!!
# 4                                         நேரம் வீண்🤛
# 5                                    വിജയ് ♥️♥️♥️♥️♥️
# 6                            நெருப்பு!!!🔥 வேற லெவல் 😎
# 7               will it be available in Hindi dubbed?
# 8                 বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9                                      மிக மிக அருமை!
# 10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11            Nalla thiraipadam pola....nalla irukum.
# 12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14  Super trailer!!!!super action, super V.i and V...
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...
#
#                                      Cleaned_Comments Source_Language  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...           tamil
# 1                     I am Vijay fan since i was kid…         english
# 2                            மிக மிக அருமையான ட்ரைலர்           tamil
# 3                       Vijay Sethupati is far better         english
# 4                                          நேரம் வீண்           tamil
# 5                                              വിജയ്        malayalam
# 6                                 நெருப்பு வேற லெவல்            tamil
# 7                will it be available in Hindi dubbed         english
# 8                   বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই         bengali
# 9                                       மிக மிக அருமை           tamil
# 10                                        තලපති විජේ          sinhala
# 11                 Nalla thiraipadam polanalla irukum           tamil
# 12       ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ          sinhala
# 13                     Anirudh  best music director           english
# 14   Super trailersuper action super Vi and VS acting         english
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...           tamil
#
#    destination_Language                                   English_Comments  \
# 0               english  It seems that the storyline of the film is better
# 1               english                    I am Vijay fan since i was kid…
# 2               english                          The most precious trailer
# 3               english                     Vijay Sethupathi is far better
# 4               english                                      Waste of time
# 5               english                                              Vijay
# 6               english                          Fire is a different level
# 7               english               will it be available in Hindi dubbed
# 8               english                 Want to see Bangladeshi Vijay fans
# 9               english                                             Decent
# 10              english                                    Boilapity Vijay
# 11              english                          Good movie is not Polonna
# 12              english                 The Lankawa set a lichoe for a gum
# 13              english                       Anirudh  best music director
# 14              english   Super trailersuper action super Vi and VS acting
# 15              english  An actor responsible for a community has inspi...
#
#                                                tokens
# 0   [It, seems, that, the, storyline, of, the, fil...
# 1           [I, am, Vijay, fan, since, i, was, kid, ]
# 2                      [The, most, precious, trailer]
# 3                [Vijay, Sethupathi, is, far, better]
# 4                                   [Waste, of, time]
# 5                                             [Vijay]
# 6                     [Fire, is, a, different, level]
# 7        [will, it, be, available, in, Hindi, dubbed]
# 8           [Want, to, see, Bangladeshi, Vijay, fans]
# 9                                            [Decent]
# 10                                 [Boilapity, Vijay]
# 11                    [Good, movie, is, not, Polonna]
# 12        [The, Lankawa, set, a, lichoe, for, a, gum]
# 13                   [Anirudh, best, music, director]
# 14  [Super, trailersuper, action, super, Vi, and, ...
# 15  [An, actor, responsible, for, a, community, ha...

# %%
# remove unwanted words

remove_words = []

remove_words.append('httpswwwyoutubecomwatchv')
remove_words.append('yjlRWSiampt')
remove_words.append('href')
remove_words.append('br')
remove_words.append('Bar')
remove_words.append('Kahatiti')
remove_words.append('ms')
remove_words.append('a')
remove_words.append('the')
remove_words.append('tha')

def remove_stop_words(cmt_tokenize):
    clean_cmt = [word for word in cmt_tokenize if word not in remove_words]
    return clean_cmt

xl_data['cleaned_tokens'] = xl_data['tokens'].apply(lambda x: remove_stop_words(x))
xl_data
# Out:
#                                     Original_Comments  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1                    I am Vijay fan since i was kid….
# 2                           மிக மிக அருமையான ட்ரைலர்.
# 3                     Vijay Sethupati is far better!!
# 4                                         நேரம் வீண்🤛
# 5                                    വിജയ് ♥️♥️♥️♥️♥️
# 6                            நெருப்பு!!!🔥 வேற லெவல் 😎
# 7               will it be available in Hindi dubbed?
# 8                 বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9                                      மிக மிக அருமை!
# 10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11            Nalla thiraipadam pola....nalla irukum.
# 12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14  Super trailer!!!!super action, super V.i and V...
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...
#
#                                      Cleaned_Comments Source_Language  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...           tamil
# 1                     I am Vijay fan since i was kid…         english
# 2                            மிக மிக அருமையான ட்ரைலர்           tamil
# 3                       Vijay Sethupati is far better         english
# 4                                          நேரம் வீண்           tamil
# 5                                              വിജയ്        malayalam
# 6                                 நெருப்பு வேற லெவல்            tamil
# 7                will it be available in Hindi dubbed         english
# 8                   বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই         bengali
# 9                                       மிக மிக அருமை           tamil
# 10                                        තලපති විජේ          sinhala
# 11                 Nalla thiraipadam polanalla irukum           tamil
# 12       ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ          sinhala
# 13                     Anirudh  best music director           english
# 14   Super trailersuper action super Vi and VS acting         english
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...           tamil
#
#    destination_Language                                   English_Comments  \
# 0               english  It seems that the storyline of the film is better
# 1               english                    I am Vijay fan since i was kid…
# 2               english                          The most precious trailer
# 3               english                     Vijay Sethupathi is far better
# 4               english                                      Waste of time
# 5               english                                              Vijay
# 6               english                          Fire is a different level
# 7               english               will it be available in Hindi dubbed
# 8               english                 Want to see Bangladeshi Vijay fans
# 9               english                                             Decent
# 10              english                                    Boilapity Vijay
# 11              english                          Good movie is not Polonna
# 12              english                 The Lankawa set a lichoe for a gum
# 13              english                       Anirudh  best music director
# 14              english   Super trailersuper action super Vi and VS acting
# 15              english  An actor responsible for a community has inspi...
#
#                                                tokens  \
# 0   [It, seems, that, the, storyline, of, the, fil...
# 1           [I, am, Vijay, fan, since, i, was, kid, ]
# 2                      [The, most, precious, trailer]
# 3                [Vijay, Sethupathi, is, far, better]
# 4                                   [Waste, of, time]
# 5                                             [Vijay]
# 6                     [Fire, is, a, different, level]
# 7        [will, it, be, available, in, Hindi, dubbed]
# 8           [Want, to, see, Bangladeshi, Vijay, fans]
# 9                                            [Decent]
# 10                                 [Boilapity, Vijay]
# 11                    [Good, movie, is, not, Polonna]
# 12        [The, Lankawa, set, a, lichoe, for, a, gum]
# 13                   [Anirudh, best, music, director]
# 14  [Super, trailersuper, action, super, Vi, and, ...
# 15  [An, actor, responsible, for, a, community, ha...
#
#                                        cleaned_tokens
# 0   [It, seems, that, storyline, of, film, is, bet...
# 1           [I, am, Vijay, fan, since, i, was, kid, ]
# 2                      [The, most, precious, trailer]
# 3                [Vijay, Sethupathi, is, far, better]
# 4                                   [Waste, of, time]
# 5                                             [Vijay]
# 6                        [Fire, is, different, level]
# 7        [will, it, be, available, in, Hindi, dubbed]
# 8           [Want, to, see, Bangladeshi, Vijay, fans]
# 9                                            [Decent]
# 10                                 [Boilapity, Vijay]
# 11                    [Good, movie, is, not, Polonna]
# 12              [The, Lankawa, set, lichoe, for, gum]
# 13                   [Anirudh, best, music, director]
# 14  [Super, trailersuper, action, super, Vi, and, ...
# 15  [An, actor, responsible, for, community, has, ...

# %%
# merge tokens

def merge_tokens(cmt):
    merge_token = " ".join(cmt)                                                                                                          
    return merge_token

xl_data['merge_tokens'] = xl_data['cleaned_tokens'].apply(lambda x: merge_tokens(x))
xl_data
# Out:
#                                     Original_Comments  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1                    I am Vijay fan since i was kid….
# 2                           மிக மிக அருமையான ட்ரைலர்.
# 3                     Vijay Sethupati is far better!!
# 4                                         நேரம் வீண்🤛
# 5                                    വിജയ് ♥️♥️♥️♥️♥️
# 6                            நெருப்பு!!!🔥 வேற லெவல் 😎
# 7               will it be available in Hindi dubbed?
# 8                 বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9                                      மிக மிக அருமை!
# 10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11            Nalla thiraipadam pola....nalla irukum.
# 12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14  Super trailer!!!!super action, super V.i and V...
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...
#
#                                      Cleaned_Comments Source_Language  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...           tamil
# 1                     I am Vijay fan since i was kid…         english
# 2                            மிக மிக அருமையான ட்ரைலர்           tamil
# 3                       Vijay Sethupati is far better         english
# 4                                          நேரம் வீண்           tamil
# 5                                              വിജയ്        malayalam
# 6                                 நெருப்பு வேற லெவல்            tamil
# 7                will it be available in Hindi dubbed         english
# 8                   বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই         bengali
# 9                                       மிக மிக அருமை           tamil
# 10                                        තලපති විජේ          sinhala
# 11                 Nalla thiraipadam polanalla irukum           tamil
# 12       ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ          sinhala
# 13                     Anirudh  best music director           english
# 14   Super trailersuper action super Vi and VS acting         english
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...           tamil
#
#    destination_Language                                   English_Comments  \
# 0               english  It seems that the storyline of the film is better
# 1               english                    I am Vijay fan since i was kid…
# 2               english                          The most precious trailer
# 3               english                     Vijay Sethupathi is far better
# 4               english                                      Waste of time
# 5               english                                              Vijay
# 6               english                          Fire is a different level
# 7               english               will it be available in Hindi dubbed
# 8               english                 Want to see Bangladeshi Vijay fans
# 9               english                                             Decent
# 10              english                                    Boilapity Vijay
# 11              english                          Good movie is not Polonna
# 12              english                 The Lankawa set a lichoe for a gum
# 13              english                       Anirudh  best music director
# 14              english   Super trailersuper action super Vi and VS acting
# 15              english  An actor responsible for a community has inspi...
#
#                                                tokens  \
# 0   [It, seems, that, the, storyline, of, the, fil...
# 1           [I, am, Vijay, fan, since, i, was, kid, ]
# 2                      [The, most, precious, trailer]
# 3                [Vijay, Sethupathi, is, far, better]
# 4                                   [Waste, of, time]
# 5                                             [Vijay]
# 6                     [Fire, is, a, different, level]
# 7        [will, it, be, available, in, Hindi, dubbed]
# 8           [Want, to, see, Bangladeshi, Vijay, fans]
# 9                                            [Decent]
# 10                                 [Boilapity, Vijay]
# 11                    [Good, movie, is, not, Polonna]
# 12        [The, Lankawa, set, a, lichoe, for, a, gum]
# 13                   [Anirudh, best, music, director]
# 14  [Super, trailersuper, action, super, Vi, and, ...
# 15  [An, actor, responsible, for, a, community, ha...
#
#                                        cleaned_tokens  \
# 0   [It, seems, that, storyline, of, film, is, bet...
# 1           [I, am, Vijay, fan, since, i, was, kid, ]
# 2                      [The, most, precious, trailer]
# 3                [Vijay, Sethupathi, is, far, better]
# 4                                   [Waste, of, time]
# 5                                             [Vijay]
# 6                        [Fire, is, different, level]
# 7        [will, it, be, available, in, Hindi, dubbed]
# 8           [Want, to, see, Bangladeshi, Vijay, fans]
# 9                                            [Decent]
# 10                                 [Boilapity, Vijay]
# 11                    [Good, movie, is, not, Polonna]
# 12              [The, Lankawa, set, lichoe, for, gum]
# 13                   [Anirudh, best, music, director]
# 14  [Super, trailersuper, action, super, Vi, and, ...
# 15  [An, actor, responsible, for, community, has, ...
#
#                                          merge_tokens
# 0           It seems that storyline of film is better
# 1                     I am Vijay fan since i was kid
# 2                           The most precious trailer
# 3                      Vijay Sethupathi is far better
# 4                                       Waste of time
# 5                                               Vijay
# 6                             Fire is different level
# 7                will it be available in Hindi dubbed
# 8                  Want to see Bangladeshi Vijay fans
# 9                                              Decent
# 10                                    Boilapity Vijay
# 11                          Good movie is not Polonna
# 12                     The Lankawa set lichoe for gum
# 13                        Anirudh best music director
# 14   Super trailersuper action super Vi and VS acting
# 15  An actor responsible for community has inspire...

# %%
# Translate to tamil

translated_tamil_words = []

for element in xl_data['merge_tokens']:
    translated_tamil_words.append(translator.translate(element, dest="ta").text)
    
xl_data['Tamil_Comments'] = translated_tamil_words
xl_data
# Out:
#                                     Original_Comments  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1                    I am Vijay fan since i was kid….
# 2                           மிக மிக அருமையான ட்ரைலர்.
# 3                     Vijay Sethupati is far better!!
# 4                                         நேரம் வீண்🤛
# 5                                    വിജയ് ♥️♥️♥️♥️♥️
# 6                            நெருப்பு!!!🔥 வேற லெவல் 😎
# 7               will it be available in Hindi dubbed?
# 8                 বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9                                      மிக மிக அருமை!
# 10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11            Nalla thiraipadam pola....nalla irukum.
# 12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14  Super trailer!!!!super action, super V.i and V...
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...
#
#                                      Cleaned_Comments Source_Language  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...           tamil
# 1                     I am Vijay fan since i was kid…         english
# 2                            மிக மிக அருமையான ட்ரைலர்           tamil
# 3                       Vijay Sethupati is far better         english
# 4                                          நேரம் வீண்           tamil
# 5                                              വിജയ്        malayalam
# 6                                 நெருப்பு வேற லெவல்            tamil
# 7                will it be available in Hindi dubbed         english
# 8                   বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই         bengali
# 9                                       மிக மிக அருமை           tamil
# 10                                        තලපති විජේ          sinhala
# 11                 Nalla thiraipadam polanalla irukum           tamil
# 12       ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ          sinhala
# 13                     Anirudh  best music director           english
# 14   Super trailersuper action super Vi and VS acting         english
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...           tamil
#
#    destination_Language                                   English_Comments  \
# 0               english  It seems that the storyline of the film is better
# 1               english                    I am Vijay fan since i was kid…
# 2               english                          The most precious trailer
# 3               english                     Vijay Sethupathi is far better
# 4               english                                      Waste of time
# 5               english                                              Vijay
# 6               english                          Fire is a different level
# 7               english               will it be available in Hindi dubbed
# 8               english                 Want to see Bangladeshi Vijay fans
# 9               english                                             Decent
# 10              english                                    Boilapity Vijay
# 11              english                          Good movie is not Polonna
# 12              english                 The Lankawa set a lichoe for a gum
# 13              english                       Anirudh  best music director
# 14              english   Super trailersuper action super Vi and VS acting
# 15              english  An actor responsible for a community has inspi...
#
#                                                tokens  \
# 0   [It, seems, that, the, storyline, of, the, fil...
# 1           [I, am, Vijay, fan, since, i, was, kid, ]
# 2                      [The, most, precious, trailer]
# 3                [Vijay, Sethupathi, is, far, better]
# 4                                   [Waste, of, time]
# 5                                             [Vijay]
# 6                     [Fire, is, a, different, level]
# 7        [will, it, be, available, in, Hindi, dubbed]
# 8           [Want, to, see, Bangladeshi, Vijay, fans]
# 9                                            [Decent]
# 10                                 [Boilapity, Vijay]
# 11                    [Good, movie, is, not, Polonna]
# 12        [The, Lankawa, set, a, lichoe, for, a, gum]
# 13                   [Anirudh, best, music, director]
# 14  [Super, trailersuper, action, super, Vi, and, ...
# 15  [An, actor, responsible, for, a, community, ha...
#
#                                        cleaned_tokens  \
# 0   [It, seems, that, storyline, of, film, is, bet...
# 1           [I, am, Vijay, fan, since, i, was, kid, ]
# 2                      [The, most, precious, trailer]
# 3                [Vijay, Sethupathi, is, far, better]
# 4                                   [Waste, of, time]
# 5                                             [Vijay]
# 6                        [Fire, is, different, level]
# 7        [will, it, be, available, in, Hindi, dubbed]
# 8           [Want, to, see, Bangladeshi, Vijay, fans]
# 9                                            [Decent]
# 10                                 [Boilapity, Vijay]
# 11                    [Good, movie, is, not, Polonna]
# 12              [The, Lankawa, set, lichoe, for, gum]
# 13                   [Anirudh, best, music, director]
# 14  [Super, trailersuper, action, super, Vi, and, ...
# 15  [An, actor, responsible, for, community, has, ...
#
#                                          merge_tokens  \
# 0           It seems that storyline of film is better
# 1                     I am Vijay fan since i was kid
# 2                           The most precious trailer
# 3                      Vijay Sethupathi is far better
# 4                                       Waste of time
# 5                                               Vijay
# 6                             Fire is different level
# 7                will it be available in Hindi dubbed
# 8                  Want to see Bangladeshi Vijay fans
# 9                                              Decent
# 10                                    Boilapity Vijay
# 11                          Good movie is not Polonna
# 12                     The Lankawa set lichoe for gum
# 13                        Anirudh best music director
# 14   Super trailersuper action super Vi and VS acting
# 15  An actor responsible for community has inspire...
#
#                                        Tamil_Comments
# 0         படத்தின் கதைக்களம் சிறந்தது என்று தெரிகிறது
# 1       நான் குழந்தையாக இருந்ததிலிருந்து விஜய் ரசிகன்
# 2                     மிகவும் விலைமதிப்பற்ற டிரெய்லர்
# 3                      விஜய் சேதுபதி மிகவும் சிறந்தது
# 4                                          நேர விரயம்
# 5                                               விஜய்
# 6                                    தீ வேறுபட்ட நிலை
# 7                      இது இந்தி டப்பிங் செய்யப்படும்
# 8   பங்களாதேஷ் விஜய் ரசிகர்களைப் பார்க்க விரும்புக...
# 9                                           ஒழுக்கமான
# 10                                     கொதிகலன் விஜய்
# 11                              நல்ல படம் பொலோனா அல்ல
# 12                      லங்காவா லிச்சோவை கம் அமைத்தது
# 13                       அனிருத் சிறந்த இசை இயக்குனர்
# 14  சூப்பர் டிரெய்லர்சப்பர் அதிரடி சூப்பர் VI மற்ற...
# 15  சமூகத்திற்கு பொறுப்பான ஒரு நடிகர் மாணவர்களை போ...

# %%
# Tamil-English dictionary

dict_tamil = {"அ":"0", "ஆ":"1", "இ":"2", "ஈ":"3", "உ":"4", "ஊ":"5", "எ":"6", "ஏ":"7", "ஐ":"8", "ஒ":"9", "ஓ":"!", "ஔ":"@",
                    "க":"#", "ங":"$", "ச":"%", "ஜ":"^", "ஞ":"&", "ட":"*", "ண":"-", "த":"+", "ந":"=", "ன":"a", "ப":"b", "ம":"c","ய":"d", "ர":"e", "ற":"f", "ல":"g", "ள":"h", "ழ":"i", "வ":"j", "ஷ":"k", "ஸ":"l", "ஹ":"m",
                    "்":"n", "ா":"o", "ி":"p", "ீ":"q", "ு":"r", "ூ":"s", "ெ":"t", "ே":"u", "ை":"v", "ொ":"w", "ோ":"x", "ௌ":"y", "ௗ":"~", "ஃ":"z"
                   }

dict_english = {"0":"A", "1":"A", "2":"I", "3":"I", "4":"U", "5":"U", "6":"E", "7":"E", "8":"AI", "9":"O", "!":"O", "@":"AU",
                        "#":"K", "$":"N", "%":"S", "^":"J", "&":"N", "*":"D", "-":"N", "+":"TH", "=":"N", "a":"N", "b":"P", "c":"M", "d":"Y", "e":"r", "f":"r", "g":"L", "h":"L", "i":"L", "j":"V", "k":"S", "l":"S", "m":"H",
                        "n":"", "o":"a", "p":"i", "q":"i", "r":"u", "s":"u", "t":"e", "u":"e", "v":"ai", "w":"o", "x":"o", "y":"au", "~":"", "z":"H"        
                    }

# %%
# convert to tamil-english code-mix data, apply algorithm for en-code and de-code

get_Letters = []
encode = []
encode_list = []

for tamil_cmt in xl_data['Tamil_Comments']:
#     print(tamil_cmt)
    for char in tamil_cmt:
        get_Letters.append(char) 
    get_Letters.append("\n ")
TL = ''.join(get_Letters)
encode = re.sub('({})'.format( '|'.join(map(re.escape, dict_tamil.keys() ))), lambda m: dict_tamil[m.group()], TL)
# print(encode)
for c in encode:
    encode_list.append(c)
# print(encode_list)

get_result = ""

for index, val in enumerate(encode):
    if val=='#' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='$' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
       
    elif val=='%' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='^' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='&' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='*' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='-' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='+' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='=' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='a' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='b' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='c' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='d' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='e' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='f' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='g' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='h' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='i' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='j' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='k' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='l' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
    elif val=='m' and encode[index+1]!='n' and encode[index+1]!='o' and encode[index+1]!='p' and encode[index+1]!='q' and encode[index+1]!='r' and encode[index+1]!='s' and encode[index+1]!='t' and encode[index+1]!='u' and encode[index+1]!='v' and encode[index+1]!='w' and encode[index+1]!='x' and encode[index+1]!='y':
        set_value = (val+dict_tamil["ா"])
        encode_list[index] = set_value
        get_result = encode_list
        
# print(get_result)
encode = ''.join(get_result)
print("========= En-Code =========", "\n", "\n", encode) 
print()

step_2 = re.sub('({})'.format('|'.join(map(re.escape, dict_english.keys() ))), lambda m: dict_english[m.group()], encode)
decode = step_2.capitalize()
print("========= De-Code(Tamil-English Code-mix Data) =========", "\n", "\n", decode)
# Out:
# ========= En-Code =========
#
#  bo*o+n+pan #o+v#n#ohocn %pfo=n+o+r 6anfr +tep#pfo+r
#  =oan #rio=n+vdo#o 2er=n+o+pgper=n+r jp^odn eo%p#oan
#  cp#ojrcn jpgvco+pbnbofnfo *petdngoen
#  jp^odn %u+rbo+p cp#ojrcn %pfo=n+o+r
#  =ueo jpeodocn
#  jp^odn
#  +q jufrbo*n*o =pgv
#  2+r 2=n+p *obnbp$n %tdndobnbo*rcn
#  bo$n#oho+ukn jp^odn eo%p#oen#ohvbn boen#n#o jpercnbr#pfuan
#  9ir#n#ocoao
#  #w+p#ogoan jp^odn
#  =ogngo bo*ocn bwgxao 0gngo
#  go$n#ojo gp%n%xjv #ocn 0cv+n+o+r
#  0aper+n %pfo=n+o 2%v 2do#n#raoen
#  %sbnboen *petdngoen%obnboen 0+peo*p %sbnboen VI cofnfrcn Vs =o*pbnbr
#  %ocs#o+n+pfn#r bwfrbnboao 9er =o*p#oen co-ojoen#ohv bx+vbnbwerhn cofnfrcn #ugp %tdndobnbo*n*o bueo%pepdoen#ohvbn bodoanbo*r+n+o 5#n#obnbo*r+n+pdrhnhoen
#
#
# ========= De-Code(Tamil-English Code-mix Data) =========
#
#  Padaththin kathaikkalam siranthathu enru therikirathu
#  nan kulanthaiyaka irunthathilirunthu vijay rasikan
#  mikavum vilaimathipparra direylar
#  vijay sethupathi mikavum siranthathu
#  nera virayam
#  vijay
#  thi verupadda nilai
#  ithu inthi dappin seyyappadum
#  pankalathes vijay rasikarkalaip parkka virumpukiren
#  olukkamana
#  kothikalan vijay
#  nalla padam polona alla
#  lankava lissovai kam amaiththathu
#  aniruth sirantha isai iyakkunar
#  suppar direylarsappar athiradi suppar vi marrum vu nadippu
#  samukaththirku poruppana oru nadikar manavarkalai pothaipporul marrum keli seyyappadda perasiriyarkalaip payanpaduththa ukkappaduththiyullar

# %%
# data spilt and store ito the list

store = []
store.append( decode.title().rstrip().split('\n'))
# print(store)

temp = []
for front_index in store:
    for second_index in front_index:
        temp.append(second_index)   
#     print(temp)


# store into the data-set
xl_data['Tanglish_Comment'] = temp 
xl_data
# Out:
#                                     Original_Comments  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1                    I am Vijay fan since i was kid….
# 2                           மிக மிக அருமையான ட்ரைலர்.
# 3                     Vijay Sethupati is far better!!
# 4                                         நேரம் வீண்🤛
# 5                                    വിജയ് ♥️♥️♥️♥️♥️
# 6                            நெருப்பு!!!🔥 வேற லெவல் 😎
# 7               will it be available in Hindi dubbed?
# 8                 বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9                                      மிக மிக அருமை!
# 10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11            Nalla thiraipadam pola....nalla irukum.
# 12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14  Super trailer!!!!super action, super V.i and V...
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...
#
#                                      Cleaned_Comments Source_Language  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...           tamil
# 1                     I am Vijay fan since i was kid…         english
# 2                            மிக மிக அருமையான ட்ரைலர்           tamil
# 3                       Vijay Sethupati is far better         english
# 4                                          நேரம் வீண்           tamil
# 5                                              വിജയ്        malayalam
# 6                                 நெருப்பு வேற லெவல்            tamil
# 7                will it be available in Hindi dubbed         english
# 8                   বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই         bengali
# 9                                       மிக மிக அருமை           tamil
# 10                                        තලපති විජේ          sinhala
# 11                 Nalla thiraipadam polanalla irukum           tamil
# 12       ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ          sinhala
# 13                     Anirudh  best music director           english
# 14   Super trailersuper action super Vi and VS acting         english
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...           tamil
#
#    destination_Language                                   English_Comments  \
# 0               english  It seems that the storyline of the film is better
# 1               english                    I am Vijay fan since i was kid…
# 2               english                          The most precious trailer
# 3               english                     Vijay Sethupathi is far better
# 4               english                                      Waste of time
# 5               english                                              Vijay
# 6               english                          Fire is a different level
# 7               english               will it be available in Hindi dubbed
# 8               english                 Want to see Bangladeshi Vijay fans
# 9               english                                             Decent
# 10              english                                    Boilapity Vijay
# 11              english                          Good movie is not Polonna
# 12              english                 The Lankawa set a lichoe for a gum
# 13              english                       Anirudh  best music director
# 14              english   Super trailersuper action super Vi and VS acting
# 15              english  An actor responsible for a community has inspi...
#
#                                                tokens  \
# 0   [It, seems, that, the, storyline, of, the, fil...
# 1           [I, am, Vijay, fan, since, i, was, kid, ]
# 2                      [The, most, precious, trailer]
# 3                [Vijay, Sethupathi, is, far, better]
# 4                                   [Waste, of, time]
# 5                                             [Vijay]
# 6                     [Fire, is, a, different, level]
# 7        [will, it, be, available, in, Hindi, dubbed]
# 8           [Want, to, see, Bangladeshi, Vijay, fans]
# 9                                            [Decent]
# 10                                 [Boilapity, Vijay]
# 11                    [Good, movie, is, not, Polonna]
# 12        [The, Lankawa, set, a, lichoe, for, a, gum]
# 13                   [Anirudh, best, music, director]
# 14  [Super, trailersuper, action, super, Vi, and, ...
# 15  [An, actor, responsible, for, a, community, ha...
#
#                                        cleaned_tokens  \
# 0   [It, seems, that, storyline, of, film, is, bet...
# 1           [I, am, Vijay, fan, since, i, was, kid, ]
# 2                      [The, most, precious, trailer]
# 3                [Vijay, Sethupathi, is, far, better]
# 4                                   [Waste, of, time]
# 5                                             [Vijay]
# 6                        [Fire, is, different, level]
# 7        [will, it, be, available, in, Hindi, dubbed]
# 8           [Want, to, see, Bangladeshi, Vijay, fans]
# 9                                            [Decent]
# 10                                 [Boilapity, Vijay]
# 11                    [Good, movie, is, not, Polonna]
# 12              [The, Lankawa, set, lichoe, for, gum]
# 13                   [Anirudh, best, music, director]
# 14  [Super, trailersuper, action, super, Vi, and, ...
# 15  [An, actor, responsible, for, community, has, ...
#
#                                          merge_tokens  \
# 0           It seems that storyline of film is better
# 1                     I am Vijay fan since i was kid
# 2                           The most precious trailer
# 3                      Vijay Sethupathi is far better
# 4                                       Waste of time
# 5                                               Vijay
# 6                             Fire is different level
# 7                will it be available in Hindi dubbed
# 8                  Want to see Bangladeshi Vijay fans
# 9                                              Decent
# 10                                    Boilapity Vijay
# 11                          Good movie is not Polonna
# 12                     The Lankawa set lichoe for gum
# 13                        Anirudh best music director
# 14   Super trailersuper action super Vi and VS acting
# 15  An actor responsible for community has inspire...
#
#                                        Tamil_Comments  \
# 0         படத்தின் கதைக்களம் சிறந்தது என்று தெரிகிறது
# 1       நான் குழந்தையாக இருந்ததிலிருந்து விஜய் ரசிகன்
# 2                     மிகவும் விலைமதிப்பற்ற டிரெய்லர்
# 3                      விஜய் சேதுபதி மிகவும் சிறந்தது
# 4                                          நேர விரயம்
# 5                                               விஜய்
# 6                                    தீ வேறுபட்ட நிலை
# 7                      இது இந்தி டப்பிங் செய்யப்படும்
# 8   பங்களாதேஷ் விஜய் ரசிகர்களைப் பார்க்க விரும்புக...
# 9                                           ஒழுக்கமான
# 10                                     கொதிகலன் விஜய்
# 11                              நல்ல படம் பொலோனா அல்ல
# 12                      லங்காவா லிச்சோவை கம் அமைத்தது
# 13                       அனிருத் சிறந்த இசை இயக்குனர்
# 14  சூப்பர் டிரெய்லர்சப்பர் அதிரடி சூப்பர் VI மற்ற...
# 15  சமூகத்திற்கு பொறுப்பான ஒரு நடிகர் மாணவர்களை போ...
#
#                                      Tanglish_Comment
# 0   Padaththin Kathaikkalam Siranthathu Enru Theri...
# 1    Nan Kulanthaiyaka Irunthathilirunthu Vijay Ra...
# 2                   Mikavum Vilaimathipparra Direylar
# 3                Vijay Sethupathi Mikavum Siranthathu
# 4                                        Nera Virayam
# 5                                               Vijay
# 6                                 Thi Verupadda Nilai
# 7                       Ithu Inthi Dappin Seyyappadum
# 8    Pankalathes Vijay Rasikarkalaip Parkka Virump...
# 9                                          Olukkamana
# 10                                   Kothikalan Vijay
# 11                            Nalla Padam Polona Alla
# 12                  Lankava Lissovai Kam Amaiththathu
# 13                    Aniruth Sirantha Isai Iyakkunar
# 14   Suppar Direylarsappar Athiradi Suppar Vi Marr...
# 15   Samukaththirku Poruppana Oru Nadikar Manavark...

# %%
# write new data-set with

df = pd.DataFrame(xl_data)

writer = pd.ExcelWriter('output_tanglish_data.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name="tanglish_translator")
writer.save()

# %% [markdown]
# ### Component-02

# %%
# import dataset

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
data_set = pd.read_excel(r'C:\Users\Sajee\Desktop\Research-2023 group\backEnd\output_tanglish_data.xlsx')
data_set
# Out:
#     Unnamed: 0                                  Original_Comments  \
# 0            0  படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1            1                   I am Vijay fan since i was kid….
# 2            2                          மிக மிக அருமையான ட்ரைலர்.
# 3            3                    Vijay Sethupati is far better!!
# 4            4                                        நேரம் வீண்🤛
# 5            5                                   വിജയ് ♥️♥️♥️♥️♥️
# 6            6                           நெருப்பு!!!🔥 வேற லெவல் 😎
# 7            7              will it be available in Hindi dubbed?
# 8            8                বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9            9                                     மிக மிக அருமை!
# 10          10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11          11            Nalla thiraipadam pola....nalla irukum.
# 12          12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13          13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14          14  Super trailer!!!!super action, super V.i and V...
# 15          15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...
#
#                                      Cleaned_Comments Source_Language  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...           tamil
# 1                     I am Vijay fan since i was kid…         english
# 2                            மிக மிக அருமையான ட்ரைலர்           tamil
# 3                       Vijay Sethupati is far better         english
# 4                                          நேரம் வீண்           tamil
# 5                                              വിജയ്        malayalam
# 6                                 நெருப்பு வேற லெவல்            tamil
# 7                will it be available in Hindi dubbed         english
# 8                   বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই         bengali
# 9                                       மிக மிக அருமை           tamil
# 10                                        තලපති විජේ          sinhala
# 11                 Nalla thiraipadam polanalla irukum           tamil
# 12       ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ          sinhala
# 13                     Anirudh  best music director           english
# 14   Super trailersuper action super Vi and VS acting         english
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...           tamil
#
#    destination_Language                                   English_Comments  \
# 0               english  It seems that the storyline of the film is better
# 1               english                    I am Vijay fan since i was kid…
# 2               english                          The most precious trailer
# 3               english                     Vijay Sethupathi is far better
# 4               english                                      Waste of time
# 5               english                                              Vijay
# 6               english                          Fire is a different level
# 7               english               will it be available in Hindi dubbed
# 8               english                 Want to see Bangladeshi Vijay fans
# 9               english                                             Decent
# 10              english                                    Boilapity Vijay
# 11              english                          Good movie is not Polonna
# 12              english                 The Lankawa set a lichoe for a gum
# 13              english                       Anirudh  best music director
# 14              english   Super trailersuper action super Vi and VS acting
# 15              english  An actor responsible for a community has inspi...
#
#                                                tokens  \
# 0   ['It', 'seems', 'that', 'the', 'storyline', 'o...
# 1   ['I', 'am', 'Vijay', 'fan', 'since', 'i', 'was...
# 2              ['The', 'most', 'precious', 'trailer']
# 3      ['Vijay', 'Sethupathi', 'is', 'far', 'better']
# 4                             ['Waste', 'of', 'time']
# 5                                           ['Vijay']
# 6           ['Fire', 'is', 'a', 'different', 'level']
# 7   ['will', 'it', 'be', 'available', 'in', 'Hindi...
# 8   ['Want', 'to', 'see', 'Bangladeshi', 'Vijay', ...
# 9                                          ['Decent']
# 10                             ['Boilapity', 'Vijay']
# 11          ['Good', 'movie', 'is', 'not', 'Polonna']
# 12  ['The', 'Lankawa', 'set', 'a', 'lichoe', 'for'...
# 13           ['Anirudh', 'best', 'music', 'director']
# 14  ['Super', 'trailersuper', 'action', 'super', '...
# 15  ['An', 'actor', 'responsible', 'for', 'a', 'co...
#
#                                        cleaned_tokens  \
# 0   ['It', 'seems', 'that', 'storyline', 'of', 'fi...
# 1   ['I', 'am', 'Vijay', 'fan', 'since', 'i', 'was...
# 2              ['The', 'most', 'precious', 'trailer']
# 3      ['Vijay', 'Sethupathi', 'is', 'far', 'better']
# 4                             ['Waste', 'of', 'time']
# 5                                           ['Vijay']
# 6                ['Fire', 'is', 'different', 'level']
# 7   ['will', 'it', 'be', 'available', 'in', 'Hindi...
# 8   ['Want', 'to', 'see', 'Bangladeshi', 'Vijay', ...
# 9                                          ['Decent']
# 10                             ['Boilapity', 'Vijay']
# 11          ['Good', 'movie', 'is', 'not', 'Polonna']
# 12  ['The', 'Lankawa', 'set', 'lichoe', 'for', 'gum']
# 13           ['Anirudh', 'best', 'music', 'director']
# 14  ['Super', 'trailersuper', 'action', 'super', '...
# 15  ['An', 'actor', 'responsible', 'for', 'communi...
#
#                                          merge_tokens  \
# 0           It seems that storyline of film is better
# 1                     I am Vijay fan since i was kid
# 2                           The most precious trailer
# 3                      Vijay Sethupathi is far better
# 4                                       Waste of time
# 5                                               Vijay
# 6                             Fire is different level
# 7                will it be available in Hindi dubbed
# 8                  Want to see Bangladeshi Vijay fans
# 9                                              Decent
# 10                                    Boilapity Vijay
# 11                          Good movie is not Polonna
# 12                     The Lankawa set lichoe for gum
# 13                        Anirudh best music director
# 14   Super trailersuper action super Vi and VS acting
# 15  An actor responsible for community has inspire...
#
#                                        Tamil_Comments  \
# 0         படத்தின் கதைக்களம் சிறந்தது என்று தெரிகிறது
# 1       நான் குழந்தையாக இருந்ததிலிருந்து விஜய் ரசிகன்
# 2                     மிகவும் விலைமதிப்பற்ற டிரெய்லர்
# 3                      விஜய் சேதுபதி மிகவும் சிறந்தது
# 4                                          நேர விரயம்
# 5                                               விஜய்
# 6                                    தீ வேறுபட்ட நிலை
# 7                      இது இந்தி டப்பிங் செய்யப்படும்
# 8   பங்களாதேஷ் விஜய் ரசிகர்களைப் பார்க்க விரும்புக...
# 9                                           ஒழுக்கமான
# 10                                     கொதிகலன் விஜய்
# 11                              நல்ல படம் பொலோனா அல்ல
# 12                      லங்காவா லிச்சோவை கம் அமைத்தது
# 13                       அனிருத் சிறந்த இசை இயக்குனர்
# 14  சூப்பர் டிரெய்லர்சப்பர் அதிரடி சூப்பர் VI மற்ற...
# 15  சமூகத்திற்கு பொறுப்பான ஒரு நடிகர் மாணவர்களை போ...
#
#                                      Tanglish_Comment
# 0   Padaththin Kathaikkalam Siranthathu Enru Theri...
# 1    Nan Kulanthaiyaka Irunthathilirunthu Vijay Ra...
# 2                   Mikavum Vilaimathipparra Direylar
# 3                Vijay Sethupathi Mikavum Siranthathu
# 4                                        Nera Virayam
# 5                                               Vijay
# 6                                 Thi Verupadda Nilai
# 7                       Ithu Inthi Dappin Seyyappadum
# 8    Pankalathes Vijay Rasikarkalaip Parkka Virump...
# 9                                          Olukkamana
# 10                                   Kothikalan Vijay
# 11                            Nalla Padam Polona Alla
# 12                  Lankava Lissovai Kam Amaiththathu
# 13                    Aniruth Sirantha Isai Iyakkunar
# 14   Suppar Direylarsappar Athiradi Suppar Vi Marr...
# 15   Samukaththirku Poruppana Oru Nadikar Manavark...

# %%
# Tokenization

def tokenize(cmt):
    tokens = re.split('\W+', cmt)
    return tokens

data_set['tanglish_token'] = data_set['Tanglish_Comment'].apply(lambda x: tokenize(x))
data_set
# Out:
#     Unnamed: 0                                  Original_Comments  \
# 0            0  படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1            1                   I am Vijay fan since i was kid….
# 2            2                          மிக மிக அருமையான ட்ரைலர்.
# 3            3                    Vijay Sethupati is far better!!
# 4            4                                        நேரம் வீண்🤛
# 5            5                                   വിജയ് ♥️♥️♥️♥️♥️
# 6            6                           நெருப்பு!!!🔥 வேற லெவல் 😎
# 7            7              will it be available in Hindi dubbed?
# 8            8                বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9            9                                     மிக மிக அருமை!
# 10          10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11          11            Nalla thiraipadam pola....nalla irukum.
# 12          12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13          13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14          14  Super trailer!!!!super action, super V.i and V...
# 15          15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...
#
#                                      Cleaned_Comments Source_Language  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...           tamil
# 1                     I am Vijay fan since i was kid…         english
# 2                            மிக மிக அருமையான ட்ரைலர்           tamil
# 3                       Vijay Sethupati is far better         english
# 4                                          நேரம் வீண்           tamil
# 5                                              വിജയ്        malayalam
# 6                                 நெருப்பு வேற லெவல்            tamil
# 7                will it be available in Hindi dubbed         english
# 8                   বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই         bengali
# 9                                       மிக மிக அருமை           tamil
# 10                                        තලපති විජේ          sinhala
# 11                 Nalla thiraipadam polanalla irukum           tamil
# 12       ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ          sinhala
# 13                     Anirudh  best music director           english
# 14   Super trailersuper action super Vi and VS acting         english
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...           tamil
#
#    destination_Language                                   English_Comments  \
# 0               english  It seems that the storyline of the film is better
# 1               english                    I am Vijay fan since i was kid…
# 2               english                          The most precious trailer
# 3               english                     Vijay Sethupathi is far better
# 4               english                                      Waste of time
# 5               english                                              Vijay
# 6               english                          Fire is a different level
# 7               english               will it be available in Hindi dubbed
# 8               english                 Want to see Bangladeshi Vijay fans
# 9               english                                             Decent
# 10              english                                    Boilapity Vijay
# 11              english                          Good movie is not Polonna
# 12              english                 The Lankawa set a lichoe for a gum
# 13              english                       Anirudh  best music director
# 14              english   Super trailersuper action super Vi and VS acting
# 15              english  An actor responsible for a community has inspi...
#
#                                                tokens  \
# 0   ['It', 'seems', 'that', 'the', 'storyline', 'o...
# 1   ['I', 'am', 'Vijay', 'fan', 'since', 'i', 'was...
# 2              ['The', 'most', 'precious', 'trailer']
# 3      ['Vijay', 'Sethupathi', 'is', 'far', 'better']
# 4                             ['Waste', 'of', 'time']
# 5                                           ['Vijay']
# 6           ['Fire', 'is', 'a', 'different', 'level']
# 7   ['will', 'it', 'be', 'available', 'in', 'Hindi...
# 8   ['Want', 'to', 'see', 'Bangladeshi', 'Vijay', ...
# 9                                          ['Decent']
# 10                             ['Boilapity', 'Vijay']
# 11          ['Good', 'movie', 'is', 'not', 'Polonna']
# 12  ['The', 'Lankawa', 'set', 'a', 'lichoe', 'for'...
# 13           ['Anirudh', 'best', 'music', 'director']
# 14  ['Super', 'trailersuper', 'action', 'super', '...
# 15  ['An', 'actor', 'responsible', 'for', 'a', 'co...
#
#                                        cleaned_tokens  \
# 0   ['It', 'seems', 'that', 'storyline', 'of', 'fi...
# 1   ['I', 'am', 'Vijay', 'fan', 'since', 'i', 'was...
# 2              ['The', 'most', 'precious', 'trailer']
# 3      ['Vijay', 'Sethupathi', 'is', 'far', 'better']
# 4                             ['Waste', 'of', 'time']
# 5                                           ['Vijay']
# 6                ['Fire', 'is', 'different', 'level']
# 7   ['will', 'it', 'be', 'available', 'in', 'Hindi...
# 8   ['Want', 'to', 'see', 'Bangladeshi', 'Vijay', ...
# 9                                          ['Decent']
# 10                             ['Boilapity', 'Vijay']
# 11          ['Good', 'movie', 'is', 'not', 'Polonna']
# 12  ['The', 'Lankawa', 'set', 'lichoe', 'for', 'gum']
# 13           ['Anirudh', 'best', 'music', 'director']
# 14  ['Super', 'trailersuper', 'action', 'super', '...
# 15  ['An', 'actor', 'responsible', 'for', 'communi...
#
#                                          merge_tokens  \
# 0           It seems that storyline of film is better
# 1                     I am Vijay fan since i was kid
# 2                           The most precious trailer
# 3                      Vijay Sethupathi is far better
# 4                                       Waste of time
# 5                                               Vijay
# 6                             Fire is different level
# 7                will it be available in Hindi dubbed
# 8                  Want to see Bangladeshi Vijay fans
# 9                                              Decent
# 10                                    Boilapity Vijay
# 11                          Good movie is not Polonna
# 12                     The Lankawa set lichoe for gum
# 13                        Anirudh best music director
# 14   Super trailersuper action super Vi and VS acting
# 15  An actor responsible for community has inspire...
#
#                                        Tamil_Comments  \
# 0         படத்தின் கதைக்களம் சிறந்தது என்று தெரிகிறது
# 1       நான் குழந்தையாக இருந்ததிலிருந்து விஜய் ரசிகன்
# 2                     மிகவும் விலைமதிப்பற்ற டிரெய்லர்
# 3                      விஜய் சேதுபதி மிகவும் சிறந்தது
# 4                                          நேர விரயம்
# 5                                               விஜய்
# 6                                    தீ வேறுபட்ட நிலை
# 7                      இது இந்தி டப்பிங் செய்யப்படும்
# 8   பங்களாதேஷ் விஜய் ரசிகர்களைப் பார்க்க விரும்புக...
# 9                                           ஒழுக்கமான
# 10                                     கொதிகலன் விஜய்
# 11                              நல்ல படம் பொலோனா அல்ல
# 12                      லங்காவா லிச்சோவை கம் அமைத்தது
# 13                       அனிருத் சிறந்த இசை இயக்குனர்
# 14  சூப்பர் டிரெய்லர்சப்பர் அதிரடி சூப்பர் VI மற்ற...
# 15  சமூகத்திற்கு பொறுப்பான ஒரு நடிகர் மாணவர்களை போ...
#
#                                      Tanglish_Comment  \
# 0   Padaththin Kathaikkalam Siranthathu Enru Theri...
# 1    Nan Kulanthaiyaka Irunthathilirunthu Vijay Ra...
# 2                   Mikavum Vilaimathipparra Direylar
# 3                Vijay Sethupathi Mikavum Siranthathu
# 4                                        Nera Virayam
# 5                                               Vijay
# 6                                 Thi Verupadda Nilai
# 7                       Ithu Inthi Dappin Seyyappadum
# 8    Pankalathes Vijay Rasikarkalaip Parkka Virump...
# 9                                          Olukkamana
# 10                                   Kothikalan Vijay
# 11                            Nalla Padam Polona Alla
# 12                  Lankava Lissovai Kam Amaiththathu
# 13                    Aniruth Sirantha Isai Iyakkunar
# 14   Suppar Direylarsappar Athiradi Suppar Vi Marr...
# 15   Samukaththirku Poruppana Oru Nadikar Manavark...
#
#                                          tokenize_cmt  \
# 0   [Padaththin, Kathaikkalam, Siranthathu, Enru, ...
# 1   [, Nan, Kulanthaiyaka, Irunthathilirunthu, Vij...
# 2             [, Mikavum, Vilaimathipparra, Direylar]
# 3         [, Vijay, Sethupathi, Mikavum, Siranthathu]
# 4                                   [, Nera, Virayam]
# 5                                           [, Vijay]
# 6                           [, Thi, Verupadda, Nilai]
# 7                [, Ithu, Inthi, Dappin, Seyyappadum]
# 8   [, Pankalathes, Vijay, Rasikarkalaip, Parkka, ...
# 9                                      [, Olukkamana]
# 10                              [, Kothikalan, Vijay]
# 11                     [, Nalla, Padam, Polona, Alla]
# 12           [, Lankava, Lissovai, Kam, Amaiththathu]
# 13             [, Aniruth, Sirantha, Isai, Iyakkunar]
# 14  [, Suppar, Direylarsappar, Athiradi, Suppar, V...
# 15  [, Samukaththirku, Poruppana, Oru, Nadikar, Ma...
#
#                                        tanglish_token
# 0   [Padaththin, Kathaikkalam, Siranthathu, Enru, ...
# 1   [, Nan, Kulanthaiyaka, Irunthathilirunthu, Vij...
# 2             [, Mikavum, Vilaimathipparra, Direylar]
# 3         [, Vijay, Sethupathi, Mikavum, Siranthathu]
# 4                                   [, Nera, Virayam]
# 5                                           [, Vijay]
# 6                           [, Thi, Verupadda, Nilai]
# 7                [, Ithu, Inthi, Dappin, Seyyappadum]
# 8   [, Pankalathes, Vijay, Rasikarkalaip, Parkka, ...
# 9                                      [, Olukkamana]
# 10                              [, Kothikalan, Vijay]
# 11                     [, Nalla, Padam, Polona, Alla]
# 12           [, Lankava, Lissovai, Kam, Amaiththathu]
# 13             [, Aniruth, Sirantha, Isai, Iyakkunar]
# 14  [, Suppar, Direylarsappar, Athiradi, Suppar, V...
# 15  [, Samukaththirku, Poruppana, Oru, Nadikar, Ma...

# %%
# Create List for positive & negative Comments

positive_list = ['nanraka', 'alakana', 'siranthathu', 'verupadda', 'virumpukiren', 'olukkamana', 'nalla', 'sirantha', 'suppar', 'maas', 'rasikan', 'geya', 'veramathi', 'nalla', 'senjudar', 'nallam', 'paarkalaam', 'senjudar', 'senjudanga', 'neruppu', 'mersal', 'next level', 'level', 'vera kaddam', 'verelevel']
negative_list = ['virayam', 'kothikalan', 'keli', 'kanravi', 'kevalam', 'asinkam', 'kevalamana', 'asinkamana', 'bore', 'boomer', 'beep', 'nallave illa', 'nalla illa', 'poor', 'mayiru', 'bad', 'failure', 'fail', 'sleep']

# %%
# calculation for rating

positive_comments_count = 0
negative_comments_count = 0

for cmt in data_set['tanglish_token']:  
            try:  
                for word in cmt:
                    if word.lower() in positive_list:
                        while word.lower() not in positive_list:
                            continue
                        positive_comments_count += 1 
#                         print(word)
                        break

                for word in cmt:
                    if word.lower() in negative_list:
                        while word.lower() not in negative_list:
                            continue
                        negative_comments_count += 1
#                         print(word)
                        break
            except:
                pass
    
print('Positive comments count : ', positive_comments_count )
print('Negative comments count : ', negative_comments_count )
# Out:
# Positive comments count :  9
# Negative comments count :  3

# %%
# get rating

positive_rating = positive_comments_count/(positive_comments_count + negative_comments_count)
print( 'Positive Comment = ',  round(positive_rating*100, 2), '%')

negative_rating = negative_comments_count/(positive_comments_count + negative_comments_count)
print( 'Negative Comment = ', round(negative_rating*100, 2), '%')
# Out:
# Positive Comment =  75.0 %
# Negative Comment =  25.0 %

# %%
# making decision

if positive_rating > negative_rating:
    print('This movie has more "positive" review than negative review...')
else:
    print('This movie has more "negative" review than positive review...')
# Out:
# This movie has more "positive" review than negative review...

# %%
# store dataset
df = pd.DataFrame(data_set)

writer = pd.ExcelWriter('output_sentiment_analysis.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name="Sentiment_Analysis")

writer.save()

# %% [markdown]
# # Component-03

# %%
# import dataset

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
data_set = pd.read_excel(r'C:\Users\Sajee\Desktop\Research-2023 group\backEnd\output_tanglish_data.xlsx')
data_set
# Out:
#     Unnamed: 0                                  Original_Comments  \
# 0            0  படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1            1                   I am Vijay fan since i was kid….
# 2            2                          மிக மிக அருமையான ட்ரைலர்.
# 3            3                    Vijay Sethupati is far better!!
# 4            4                                        நேரம் வீண்🤛
# 5            5                                   വിജയ് ♥️♥️♥️♥️♥️
# 6            6                           நெருப்பு!!!🔥 வேற லெவல் 😎
# 7            7              will it be available in Hindi dubbed?
# 8            8                বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9            9                                     மிக மிக அருமை!
# 10          10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11          11            Nalla thiraipadam pola....nalla irukum.
# 12          12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13          13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14          14  Super trailer!!!!super action, super V.i and V...
# 15          15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...
#
#                                      Cleaned_Comments Source_Language  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...           tamil
# 1                     I am Vijay fan since i was kid…         english
# 2                            மிக மிக அருமையான ட்ரைலர்           tamil
# 3                       Vijay Sethupati is far better         english
# 4                                          நேரம் வீண்           tamil
# 5                                              വിജയ്        malayalam
# 6                                 நெருப்பு வேற லெவல்            tamil
# 7                will it be available in Hindi dubbed         english
# 8                   বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই         bengali
# 9                                       மிக மிக அருமை           tamil
# 10                                        තලපති විජේ          sinhala
# 11                 Nalla thiraipadam polanalla irukum           tamil
# 12       ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ          sinhala
# 13                     Anirudh  best music director           english
# 14   Super trailersuper action super Vi and VS acting         english
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...           tamil
#
#    destination_Language                                   English_Comments  \
# 0               english  It seems that the storyline of the film is better
# 1               english                    I am Vijay fan since i was kid…
# 2               english                          The most precious trailer
# 3               english                     Vijay Sethupathi is far better
# 4               english                                      Waste of time
# 5               english                                              Vijay
# 6               english                          Fire is a different level
# 7               english               will it be available in Hindi dubbed
# 8               english                 Want to see Bangladeshi Vijay fans
# 9               english                                             Decent
# 10              english                                    Boilapity Vijay
# 11              english                          Good movie is not Polonna
# 12              english                 The Lankawa set a lichoe for a gum
# 13              english                       Anirudh  best music director
# 14              english   Super trailersuper action super Vi and VS acting
# 15              english  An actor responsible for a community has inspi...
#
#                                                tokens  \
# 0   ['It', 'seems', 'that', 'the', 'storyline', 'o...
# 1   ['I', 'am', 'Vijay', 'fan', 'since', 'i', 'was...
# 2              ['The', 'most', 'precious', 'trailer']
# 3      ['Vijay', 'Sethupathi', 'is', 'far', 'better']
# 4                             ['Waste', 'of', 'time']
# 5                                           ['Vijay']
# 6           ['Fire', 'is', 'a', 'different', 'level']
# 7   ['will', 'it', 'be', 'available', 'in', 'Hindi...
# 8   ['Want', 'to', 'see', 'Bangladeshi', 'Vijay', ...
# 9                                          ['Decent']
# 10                             ['Boilapity', 'Vijay']
# 11          ['Good', 'movie', 'is', 'not', 'Polonna']
# 12  ['The', 'Lankawa', 'set', 'a', 'lichoe', 'for'...
# 13           ['Anirudh', 'best', 'music', 'director']
# 14  ['Super', 'trailersuper', 'action', 'super', '...
# 15  ['An', 'actor', 'responsible', 'for', 'a', 'co...
#
#                                        cleaned_tokens  \
# 0   ['It', 'seems', 'that', 'storyline', 'of', 'fi...
# 1   ['I', 'am', 'Vijay', 'fan', 'since', 'i', 'was...
# 2              ['The', 'most', 'precious', 'trailer']
# 3      ['Vijay', 'Sethupathi', 'is', 'far', 'better']
# 4                             ['Waste', 'of', 'time']
# 5                                           ['Vijay']
# 6                ['Fire', 'is', 'different', 'level']
# 7   ['will', 'it', 'be', 'available', 'in', 'Hindi...
# 8   ['Want', 'to', 'see', 'Bangladeshi', 'Vijay', ...
# 9                                          ['Decent']
# 10                             ['Boilapity', 'Vijay']
# 11          ['Good', 'movie', 'is', 'not', 'Polonna']
# 12  ['The', 'Lankawa', 'set', 'lichoe', 'for', 'gum']
# 13           ['Anirudh', 'best', 'music', 'director']
# 14  ['Super', 'trailersuper', 'action', 'super', '...
# 15  ['An', 'actor', 'responsible', 'for', 'communi...
#
#                                          merge_tokens  \
# 0           It seems that storyline of film is better
# 1                     I am Vijay fan since i was kid
# 2                           The most precious trailer
# 3                      Vijay Sethupathi is far better
# 4                                       Waste of time
# 5                                               Vijay
# 6                             Fire is different level
# 7                will it be available in Hindi dubbed
# 8                  Want to see Bangladeshi Vijay fans
# 9                                              Decent
# 10                                    Boilapity Vijay
# 11                          Good movie is not Polonna
# 12                     The Lankawa set lichoe for gum
# 13                        Anirudh best music director
# 14   Super trailersuper action super Vi and VS acting
# 15  An actor responsible for community has inspire...
#
#                                        Tamil_Comments  \
# 0         படத்தின் கதைக்களம் சிறந்தது என்று தெரிகிறது
# 1       நான் குழந்தையாக இருந்ததிலிருந்து விஜய் ரசிகன்
# 2                     மிகவும் விலைமதிப்பற்ற டிரெய்லர்
# 3                      விஜய் சேதுபதி மிகவும் சிறந்தது
# 4                                          நேர விரயம்
# 5                                               விஜய்
# 6                                    தீ வேறுபட்ட நிலை
# 7                      இது இந்தி டப்பிங் செய்யப்படும்
# 8   பங்களாதேஷ் விஜய் ரசிகர்களைப் பார்க்க விரும்புக...
# 9                                           ஒழுக்கமான
# 10                                     கொதிகலன் விஜய்
# 11                              நல்ல படம் பொலோனா அல்ல
# 12                      லங்காவா லிச்சோவை கம் அமைத்தது
# 13                       அனிருத் சிறந்த இசை இயக்குனர்
# 14  சூப்பர் டிரெய்லர்சப்பர் அதிரடி சூப்பர் VI மற்ற...
# 15  சமூகத்திற்கு பொறுப்பான ஒரு நடிகர் மாணவர்களை போ...
#
#                                      Tanglish_Comment
# 0   Padaththin Kathaikkalam Siranthathu Enru Theri...
# 1    Nan Kulanthaiyaka Irunthathilirunthu Vijay Ra...
# 2                   Mikavum Vilaimathipparra Direylar
# 3                Vijay Sethupathi Mikavum Siranthathu
# 4                                        Nera Virayam
# 5                                               Vijay
# 6                                 Thi Verupadda Nilai
# 7                       Ithu Inthi Dappin Seyyappadum
# 8    Pankalathes Vijay Rasikarkalaip Parkka Virump...
# 9                                          Olukkamana
# 10                                   Kothikalan Vijay
# 11                            Nalla Padam Polona Alla
# 12                  Lankava Lissovai Kam Amaiththathu
# 13                    Aniruth Sirantha Isai Iyakkunar
# 14   Suppar Direylarsappar Athiradi Suppar Vi Marr...
# 15   Samukaththirku Poruppana Oru Nadikar Manavark...

# %%
# Tokenization

def tokenize(cmt):
    tokens = re.split('\W+', cmt)
    return tokens

data_set['tokenize_cmt'] = data_set['Tanglish_Comment'].apply(lambda x: tokenize(x))
data_set
# Out:
#     Unnamed: 0                                  Original_Comments  \
# 0            0  படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...
# 1            1                   I am Vijay fan since i was kid….
# 2            2                          மிக மிக அருமையான ட்ரைலர்.
# 3            3                    Vijay Sethupati is far better!!
# 4            4                                        நேரம் வீண்🤛
# 5            5                                   വിജയ് ♥️♥️♥️♥️♥️
# 6            6                           நெருப்பு!!!🔥 வேற லெவல் 😎
# 7            7              will it be available in Hindi dubbed?
# 8            8                বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই✌️
# 9            9                                     மிக மிக அருமை!
# 10          10                                 තලපති විජේ 🥰🥰🥰🥳🥳🤟🤟
# 11          11            Nalla thiraipadam pola....nalla irukum.
# 12          12     ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ 😍😇
# 13          13               Anirudh ❤ best music director  ❤❤❤❤😍
# 14          14  Super trailer!!!!super action, super V.i and V...
# 15          15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...
#
#                                      Cleaned_Comments Source_Language  \
# 0   படத்தின் கதைக்களம் நன்றாக இருக்கும் என்று தெரி...           tamil
# 1                     I am Vijay fan since i was kid…         english
# 2                            மிக மிக அருமையான ட்ரைலர்           tamil
# 3                       Vijay Sethupati is far better         english
# 4                                          நேரம் வீண்           tamil
# 5                                              വിജയ്        malayalam
# 6                                 நெருப்பு வேற லெவல்            tamil
# 7                will it be available in Hindi dubbed         english
# 8                   বাংলাদেশি বিজয় ফ্যানদের দেখতে চাই         bengali
# 9                                       மிக மிக அருமை           tamil
# 10                                        තලපති විජේ          sinhala
# 11                 Nalla thiraipadam polanalla irukum           tamil
# 12       ලන්කාවෙ සෙට් එක ගැම්මට ලයික් එකක් දාගෙන යමූ          sinhala
# 13                     Anirudh  best music director           english
# 14   Super trailersuper action super Vi and VS acting         english
# 15  ஒரு சமூகத்தில் பொறுப்புள்ள ஒரு நடிகன் மாணவர்கள...           tamil
#
#    destination_Language                                   English_Comments  \
# 0               english  It seems that the storyline of the film is better
# 1               english                    I am Vijay fan since i was kid…
# 2               english                          The most precious trailer
# 3               english                     Vijay Sethupathi is far better
# 4               english                                      Waste of time
# 5               english                                              Vijay
# 6               english                          Fire is a different level
# 7               english               will it be available in Hindi dubbed
# 8               english                 Want to see Bangladeshi Vijay fans
# 9               english                                             Decent
# 10              english                                    Boilapity Vijay
# 11              english                          Good movie is not Polonna
# 12              english                 The Lankawa set a lichoe for a gum
# 13              english                       Anirudh  best music director
# 14              english   Super trailersuper action super Vi and VS acting
# 15              english  An actor responsible for a community has inspi...
#
#                                                tokens  \
# 0   ['It', 'seems', 'that', 'the', 'storyline', 'o...
# 1   ['I', 'am', 'Vijay', 'fan', 'since', 'i', 'was...
# 2              ['The', 'most', 'precious', 'trailer']
# 3      ['Vijay', 'Sethupathi', 'is', 'far', 'better']
# 4                             ['Waste', 'of', 'time']
# 5                                           ['Vijay']
# 6           ['Fire', 'is', 'a', 'different', 'level']
# 7   ['will', 'it', 'be', 'available', 'in', 'Hindi...
# 8   ['Want', 'to', 'see', 'Bangladeshi', 'Vijay', ...
# 9                                          ['Decent']
# 10                             ['Boilapity', 'Vijay']
# 11          ['Good', 'movie', 'is', 'not', 'Polonna']
# 12  ['The', 'Lankawa', 'set', 'a', 'lichoe', 'for'...
# 13           ['Anirudh', 'best', 'music', 'director']
# 14  ['Super', 'trailersuper', 'action', 'super', '...
# 15  ['An', 'actor', 'responsible', 'for', 'a', 'co...
#
#                                        cleaned_tokens  \
# 0   ['It', 'seems', 'that', 'storyline', 'of', 'fi...
# 1   ['I', 'am', 'Vijay', 'fan', 'since', 'i', 'was...
# 2              ['The', 'most', 'precious', 'trailer']
# 3      ['Vijay', 'Sethupathi', 'is', 'far', 'better']
# 4                             ['Waste', 'of', 'time']
# 5                                           ['Vijay']
# 6                ['Fire', 'is', 'different', 'level']
# 7   ['will', 'it', 'be', 'available', 'in', 'Hindi...
# 8   ['Want', 'to', 'see', 'Bangladeshi', 'Vijay', ...
# 9                                          ['Decent']
# 10                             ['Boilapity', 'Vijay']
# 11          ['Good', 'movie', 'is', 'not', 'Polonna']
# 12  ['The', 'Lankawa', 'set', 'lichoe', 'for', 'gum']
# 13           ['Anirudh', 'best', 'music', 'director']
# 14  ['Super', 'trailersuper', 'action', 'super', '...
# 15  ['An', 'actor', 'responsible', 'for', 'communi...
#
#                                          merge_tokens  \
# 0           It seems that storyline of film is better
# 1                     I am Vijay fan since i was kid
# 2                           The most precious trailer
# 3                      Vijay Sethupathi is far better
# 4                                       Waste of time
# 5                                               Vijay
# 6                             Fire is different level
# 7                will it be available in Hindi dubbed
# 8                  Want to see Bangladeshi Vijay fans
# 9                                              Decent
# 10                                    Boilapity Vijay
# 11                          Good movie is not Polonna
# 12                     The Lankawa set lichoe for gum
# 13                        Anirudh best music director
# 14   Super trailersuper action super Vi and VS acting
# 15  An actor responsible for community has inspire...
#
#                                        Tamil_Comments  \
# 0         படத்தின் கதைக்களம் சிறந்தது என்று தெரிகிறது
# 1       நான் குழந்தையாக இருந்ததிலிருந்து விஜய் ரசிகன்
# 2                     மிகவும் விலைமதிப்பற்ற டிரெய்லர்
# 3                      விஜய் சேதுபதி மிகவும் சிறந்தது
# 4                                          நேர விரயம்
# 5                                               விஜய்
# 6                                    தீ வேறுபட்ட நிலை
# 7                      இது இந்தி டப்பிங் செய்யப்படும்
# 8   பங்களாதேஷ் விஜய் ரசிகர்களைப் பார்க்க விரும்புக...
# 9                                           ஒழுக்கமான
# 10                                     கொதிகலன் விஜய்
# 11                              நல்ல படம் பொலோனா அல்ல
# 12                      லங்காவா லிச்சோவை கம் அமைத்தது
# 13                       அனிருத் சிறந்த இசை இயக்குனர்
# 14  சூப்பர் டிரெய்லர்சப்பர் அதிரடி சூப்பர் VI மற்ற...
# 15  சமூகத்திற்கு பொறுப்பான ஒரு நடிகர் மாணவர்களை போ...
#
#                                      Tanglish_Comment  \
# 0   Padaththin Kathaikkalam Siranthathu Enru Theri...
# 1    Nan Kulanthaiyaka Irunthathilirunthu Vijay Ra...
# 2                   Mikavum Vilaimathipparra Direylar
# 3                Vijay Sethupathi Mikavum Siranthathu
# 4                                        Nera Virayam
# 5                                               Vijay
# 6                                 Thi Verupadda Nilai
# 7                       Ithu Inthi Dappin Seyyappadum
# 8    Pankalathes Vijay Rasikarkalaip Parkka Virump...
# 9                                          Olukkamana
# 10                                   Kothikalan Vijay
# 11                            Nalla Padam Polona Alla
# 12                  Lankava Lissovai Kam Amaiththathu
# 13                    Aniruth Sirantha Isai Iyakkunar
# 14   Suppar Direylarsappar Athiradi Suppar Vi Marr...
# 15   Samukaththirku Poruppana Oru Nadikar Manavark...
#
#                                          tokenize_cmt
# 0   [Padaththin, Kathaikkalam, Siranthathu, Enru, ...
# 1   [, Nan, Kulanthaiyaka, Irunthathilirunthu, Vij...
# 2             [, Mikavum, Vilaimathipparra, Direylar]
# 3         [, Vijay, Sethupathi, Mikavum, Siranthathu]
# 4                                   [, Nera, Virayam]
# 5                                           [, Vijay]
# 6                           [, Thi, Verupadda, Nilai]
# 7                [, Ithu, Inthi, Dappin, Seyyappadum]
# 8   [, Pankalathes, Vijay, Rasikarkalaip, Parkka, ...
# 9                                      [, Olukkamana]
# 10                              [, Kothikalan, Vijay]
# 11                     [, Nalla, Padam, Polona, Alla]
# 12           [, Lankava, Lissovai, Kam, Amaiththathu]
# 13             [, Aniruth, Sirantha, Isai, Iyakkunar]
# 14  [, Suppar, Direylarsappar, Athiradi, Suppar, V...
# 15  [, Samukaththirku, Poruppana, Oru, Nadikar, Ma...

# %%
# Create list for comedy, action & love

comedy_list = ['sirippu', 'siriththan', 'comedy', 'nakaisuvai']

action_list = ['sandai', 'sandaikal', 'sandaikasikal', 'thi', 'Kothikalan', 'Athiradi', 'kathaikkalam']

love_list = ['kathal', 'lovers', 'kathalarkal', 'kathalar', 'kaviyam', 'virumpukiren', 'olukkamana', 'alakana']

horror_list = ['payama', 'payanthudan', 'thikil', 'pei', 'payankaram']

# %%
# calculation for rating

comedy_comments_count = 1
action_comments_count = 1
love_comments_count = 1
horror_comments_count = 1

for cmt in data_set['tokenize_cmt']:  
            try:  
                for word in cmt:
                    if word.lower() in comedy_list:
                        while word.lower() not in comedy_list:
                            continue
                        comedy_comments_count += 1 
                        # print(word)
                        break

                for word in cmt:
                    if word.lower() in action_list:
                        while word.lower() not in action_list:
                            continue
                        action_comments_count += 1
                        # print(word)
                        break

                for word in cmt:
                    if word.lower() in love_list:
                        while word.lower() not in love_list:
                            continue
                        love_comments_count += 1
                        # print(word)
                        break

                for word in cmt:
                    if word.lower() in horror_list:
                        while word.lower() not in horror_list:
                            continue
                        horror_comments_count += 1
                        # print(word)
                        break
            except:
                pass
    
print('Action comments count : ', action_comments_count )
print('Comedy comments count : ', comedy_comments_count )
print('Love comments count : ', love_comments_count )
print('Horror comments count : ', horror_comments_count )
# Out:
# Action comments count :  3
# Comedy comments count :  1
# Love comments count :  3
# Horror comments count :  1

# %%
# get rating

action = action_comments_count/(action_comments_count + comedy_comments_count + love_comments_count + horror_comments_count)
print( 'Action Comment = ',  round(action*100, 2), '%')
comedy = comedy_comments_count/(action_comments_count + comedy_comments_count + love_comments_count + horror_comments_count)
print( 'Comedy Comment = ',  round(comedy*100, 2), '%')

love = love_comments_count/(action_comments_count + comedy_comments_count + love_comments_count + horror_comments_count)
print( 'Love Comment = ',  round(love*100, 2), '%')

horror = horror_comments_count/(action_comments_count + comedy_comments_count + love_comments_count + horror_comments_count)
print( 'Horror Comment = ',  round(horror*100, 2), '%')


rating = [action, comedy, love, horror]
# Out:
# Action Comment =  37.5 %
# Comedy Comment =  12.5 %
# Love Comment =  37.5 %
# Horror Comment =  12.5 %

# %%
# making decision

if comedy>action and comedy>love and comedy>horror:
    print('It is a Comedy genre movie!')
elif action>comedy and action>love and action>horror:
    print('It is a Action genre movie!')
elif love>comedy and love>action and love>horror:
    print('It is a Love genre movie!')
elif horror>comedy and horror>action and horror>love:
    print('It is a Horror genre movie!')
elif (comedy==action) and (comedy>love and comedy>horror):
    print('It is a Comedy & Action genres movie!')
elif (comedy==love) and (comedy>action and comedy>horror):
    print('It is a Comedy & Love genres movie!')
elif (comedy==horror) and (comedy>love and comedy>action):
    print('It is a Comedy & Horror genres movie!')
elif (action==love) and (action>comedy and action>horror):
    print('It is a Action & Love genres movie!')
elif (action==horror) and (action>comedy and action>love):
    print('It is a Action & Horror genres movie!')
elif (love==horror) and (love>comedy and love>action):
    print('It is a Love & Horror genres movie!')
# Out:
# It is a Action & Love genres movie!

# %%
#  store dataset

df = pd.DataFrame(data_set)

writer = pd.ExcelWriter('output_movie_genre.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name="tokenization_list")

writer.save()
